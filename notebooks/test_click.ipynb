# %%
from clickhouse_driver import Client

client = Client(host='10.61.41.125' ,port='8123', user='a_slambekov', password='FSMS123')

# %%
try:
    client.ping()
    print("Connection successful")
except Exception as e:
    print(f"Connection failed: {str(e)}")
# Out:
# Connection failed: 'Client' object has no attribute 'ping'

# %%
client.ping( )
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 client.ping()
#
# AttributeError: 'Client' object has no attribute 'ping'
